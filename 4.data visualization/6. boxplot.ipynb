# %%
import matplotlib.pyplot as plt
data=[10,20,30,40]
plt.boxplot(data)
plt.show()

# %%
data1=[1,2,3,6,7,9]
data2=[3,5,5,4,7,6,6,8,7,9]
data=[data1,data2]
plt.boxplot(data)
plt.show()

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,5),columns=['a','b','c','d','e'])
df.plot.box()

# %%
df.plot(kind='box')

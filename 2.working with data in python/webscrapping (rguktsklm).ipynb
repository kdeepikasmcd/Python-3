# %%
#extracting first link from the website
page="welcome to <a href='https://www.yahoo.com'>the yahoo link"
print(page)
def geturl(page):
    a=page.find("<a href")
    b=page.find("'",a)
    c=page.find("'",b+1)
    url=page[b+1:c]
    return url
url=geturl(page)
print("****LINkS****")
print(url)
# Out:
# welcome to <a href='https://www.yahoo.com'>the yahoo link
# ****LINkS****
# https://www.yahoo.com

# %%
#extracting all links from the website
import urllib.request
url="https://rguktsklm.ac.in/"
resp=urllib.request.urlopen(url)
page1=resp.read()
page=str(page1)
def geturl(page):
    a=page.find("<a href")
    b=page.find("",a)
    c=page.find("",b+1)
    url=page[b+1:c]
    return url,end      #insted of end it is c
while True:
    c,n=geturl(page)
    page=page[n:]
    if url:
        print(url)
    else:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e057957a417> in <module>
#      12     return url,end      #insted of end it is c
#      13 while True:
# ---> 14     c,n=geturl(page)
#      15     page=page[n:]
#      16     if url:
#
# <ipython-input-2-9e057957a417> in geturl(page)
#      10     c=page.find("",b+1)
#      11     url=page[b+1:c]
# ---> 12     return url,end      #insted of end it is c
#      13 while True:
#      14     c,n=geturl(page)
#
# NameError: name 'end' is not defined

# %%
import requests
page=requests.get('https://rguktsklm.ac.in/')
print(page)
print(page.url)
# Out:
# <Response [200]>
# https://rguktsklm.ac.in/

# %%
import requests
from bs4 import BeautifulSoup
url="https://rguktsklm.ac.in/"
reqs=requests.get(url)
soup=BeautifulSoup(reqs.text,'html.parser')
for link in soup.findall('a'):
    print(link.grt('href'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-051e6d8a83e7> in <module>
#       4 reqs=requests.get(url)
#       5 soup=BeautifulSoup(reqs.text,'html.parser')
# ----> 6 for link in soup.findall('a'):
#       7     print(link.grt('href'))
#
# TypeError: 'NoneType' object is not callable

# %%
import requests
from bs4 import BeautifulSoup
page=requests.get("https://www.rgukt.in/")     #https://www.rgukt.in/
print(page)
print(page.url)
# Out:
# <Response [406]>
# https://www.rgukt.in/

# %%
import requests
from bs4 import BeautifulSoup
page=requests.get("https://www.rguktsklm.ac.in/")
a=BeautifulSoup(page.content,'html.parser')
print(a)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <!--===META DATA SECTION===-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!--===META DATA SECTION ENDS===-->
# <!--============== Meta Tags Code Starts ===============-->
# <meta content="Rajiv Gandhi University of Knowledge Technologies is a state university located in Etcherla, Srikakulam District, Andhra Pradesh, India." name="description">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="iiit,rgukt,iiits,rgukts,iiitsklm, RGUKT SKLM,sklm,rguktsklm, IIIT Srikakulam, Rgukt srikakulam,iiitsrikakulam,rguktsrikakulam,AP state university, Rajiv gandhi university of knowledge Technologies, RGUKT AP" name="keywords"/>
# <meta content="width=device-width,initial-scale=1.0,  shrink-to-fit=no" name="viewport"/>
# ...

# %%
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!--===META DATA SECTION===-->
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <!--===META DATA SECTION ENDS===-->
#   <!--============== Meta Tags Code Starts ===============-->
#   <meta content="Rajiv Gandhi University of Knowledge Technologies is a state university located in Etcherla, Srikakulam District, Andhra Pradesh, India." name="description">
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#     <meta content="iiit,rgukt,iiits,rgukts,iiitsklm, RGUKT SKLM,sklm,rguktsklm, IIIT Srikakulam, Rgukt srikakulam,iiitsrikakulam,rguktsrikakulam,AP state university, Rajiv gandhi university of knowledge Technologies, RGUKT AP" name="keywords"/>
#     <meta content="width=device-width,initial-scale=1.0,  shrink-to-fit=no" name="viewport"/>
# ...

# %%
print(page.content)
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" dir="ltr">\n  <head>\n    <!--===META DATA SECTION===-->\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n    <!--===META DATA SECTION ENDS===-->\n    \n    \n     <!--============== Meta Tags Code Starts ===============-->\n  \t<meta name="description" content="Rajiv Gandhi University of Knowledge Technologies is a state university located in Etcherla, Srikakulam District, Andhra Pradesh, India."/>\n  \t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n  \t<meta name="keywords" content="iiit,rgukt,iiits,rgukts,iiitsklm, RGUKT SKLM,sklm,rguktsklm, IIIT Srikakulam, Rgukt srikakulam,iiitsrikakulam,rguktsrikakulam,AP state university, Rajiv gandhi university of knowledge Technologies, RGUKT AP"/>\n  \t<meta name="viewport" content="width=device-width,initial-scale=1.0,  shrink-to-fit=no">\n  \t<meta name="author" content="Jaya Krishna, Vamsi Krishna Kodimela
# ...

# %%
print(a.title)
# Out:
# <title>Rajiv Gandhi University of Knowledge Technologies-AP., Srikakulam Campus</title>

# %%
print(a.title.text)
# Out:
# Rajiv Gandhi University of Knowledge Technologies-AP., Srikakulam Campus

# %%
print(a.title.name)
# Out:
# title

# %%
print(a.title.parent.name)
# Out:
# meta

# %%
print(a.body)
# Out:
# <body>
# <div class="header">
# <header class="m-auto">
# <img alt="" class="img" src="assets/images/header.png"/>
# </header>
# <nav class="container navbar-expand-md navbar-dark bg-transparent text-light">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav container">
# <li class="nav-item col-12 col-md-2 active">
# <a class="nav-link" href="index.php">Home</a>
# </li>
# <li class="nav-item dropdown col-12 col-md-2">
# <a class="nav-link dropdown-toggle" data-submenu="" data-toggle="dropdown" tabindex="0">
#                 Our University
#               </a>
# <div class="dropdown-menu">
# <div class="dropdown dropright dropdown-submenu">
# ...

# %%
print(a.head)
# Out:
# <head>
# <!--===META DATA SECTION===-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!--===META DATA SECTION ENDS===-->
# <!--============== Meta Tags Code Starts ===============-->
# <meta content="Rajiv Gandhi University of Knowledge Technologies is a state university located in Etcherla, Srikakulam District, Andhra Pradesh, India." name="description">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="iiit,rgukt,iiits,rgukts,iiitsklm, RGUKT SKLM,sklm,rguktsklm, IIIT Srikakulam, Rgukt srikakulam,iiitsrikakulam,rguktsrikakulam,AP state university, Rajiv gandhi university of knowledge Technologies, RGUKT AP" name="keywords"/>
# <meta content="width=device-width,initial-scale=1.0,  shrink-to-fit=no" name="viewport"/>
# <meta content="Jaya Krishna, Vamsi Krishna Kodimela, Gurunadh Pukkalla, Kiran Siva Sai, Deepak Grandi" name="author"/>
# ...

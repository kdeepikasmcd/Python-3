# %%
import pandas as pd
data=pd.read_csv("sales_record.csv")
print(data)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
data.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
data.count()
# Out:
# Region            1000
# Country           1000
# Item Type         1000
# Sales Channel     1000
# Order Priority    1000
# Order Date        1000
# Order ID          1000
# Ship Date         1000
# Units Sold        1000
# Unit Price        1000
# Unit Cost         1000
# Total Revenue     1000
# Total Cost        1000
# Total Profit      1000
# dtype: int64

# %%
data.max()
# Out:
# Region            Sub-Saharan Africa
# Country                     Zimbabwe
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                  9/8/2015
# Order ID                   995529830
# Ship Date                   9/9/2016
# Units Sold                      9998
# Unit Price                    668.27
# Unit Cost                     524.96
# Total Revenue            6.61721e+06
# Total Cost               5.20498e+06
# Total Profit             1.72618e+06
# dtype: object

# %%
data.min()
# Out:
# Region                   Asia
# Country           Afghanistan
# Item Type           Baby Food
# Sales Channel         Offline
# Order Priority              C
# Order Date           1/1/2010
# Order ID            102928006
# Ship Date            1/1/2013
# Units Sold                 13
# Unit Price               9.33
# Unit Cost                6.92
# Total Revenue         2043.25
# Total Cost            1416.75
# Total Profit           532.61
# dtype: object

# %%
data.isnull()
# Out:
#      Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0     False    False      False          False           False       False
# 1     False    False      False          False           False       False
# 2     False    False      False          False           False       False
# 3     False    False      False          False           False       False
# 4     False    False      False          False           False       False
# ..      ...      ...        ...            ...             ...         ...
# 995   False    False      False          False           False       False
# 996   False    False      False          False           False       False
# 997   False    False      False          False           False       False
# 998   False    False      False          False           False       False
# 999   False    False      False          False           False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
data.head(35)
# Out:
#                                Region                         Country  \
# 0        Middle East and North Africa                           Libya
# 1                       North America                          Canada
# 2        Middle East and North Africa                           Libya
# 3                                Asia                           Japan
# 4                  Sub-Saharan Africa                            Chad
# 5                              Europe                         Armenia
# 6                  Sub-Saharan Africa                         Eritrea
# 7                              Europe                      Montenegro
# 8   Central America and the Caribbean                         Jamaica
# 9               Australia and Oceania                            Fiji
# 10                 Sub-Saharan Africa                            Togo
# 11                             Europe                      Montenegro
# ...

# %%
data.tail(10)
# Out:
#                            Region               Country   Item Type  \
# 990            Sub-Saharan Africa                  Mali   Beverages
# 991            Sub-Saharan Africa               Liberia      Cereal
# 992                        Europe           Switzerland   Beverages
# 993         Australia and Oceania                Samoa    Baby Food
# 994                          Asia                 Nepal        Meat
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 990        Online              L   3/17/2012  410452497  3/26/2012
# 991       Offline              H  12/17/2015  642683303  1/20/2016
# ...

# %%
ab=data.head(36)
print(ab)
# Out:
#                                Region                         Country  \
# 0        Middle East and North Africa                           Libya
# 1                       North America                          Canada
# 2        Middle East and North Africa                           Libya
# 3                                Asia                           Japan
# 4                  Sub-Saharan Africa                            Chad
# 5                              Europe                         Armenia
# 6                  Sub-Saharan Africa                         Eritrea
# 7                              Europe                      Montenegro
# 8   Central America and the Caribbean                         Jamaica
# 9               Australia and Oceania                            Fiji
# 10                 Sub-Saharan Africa                            Togo
# 11                             Europe                      Montenegro
# ...

# %%
ab.tail(10)
# Out:
#                                Region            Country        Item Type  \
# 26                 Sub-Saharan Africa            Senegal        Beverages
# 27                      North America          Greenland           Fruits
# 28                 Sub-Saharan Africa               Chad             Meat
# 29                 Sub-Saharan Africa         Mauritius     Personal Care
# 30       Middle East and North Africa            Morocco        Beverages
# 31  Central America and the Caribbean           Honduras  Office Supplies
# 32                 Sub-Saharan Africa              Benin           Fruits
# 33                             Europe             Greece        Baby Food
# 34  Central America and the Caribbean            Jamaica        Beverages
# 35                 Sub-Saharan Africa  Equatorial Guinea  Office Supplies
#
#    Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 26       Offline              M  10/22/2014  683927953   11/4/2014
# ...

# %%
data["Country"]
# Out:
# 0                     Libya
# 1                    Canada
# 2                     Libya
# 3                     Japan
# 4                      Chad
#                ...
# 995              Azerbaijan
# 996                 Georgia
# 997    United Arab Emirates
# 998                 Finland
# 999                Portugal
# Name: Country, Length: 1000, dtype: object

# %%
data.loc[999]
# Out:
# Region               Europe
# Country            Portugal
# Item Type            Cereal
# Sales Channel       Offline
# Order Priority            C
# Order Date        4/10/2014
# Order ID          811546599
# Ship Date          5/8/2014
# Units Sold             3528
# Unit Price            205.7
# Unit Cost            117.11
# Total Revenue        725710
# Total Cost           413164
# Total Profit         312546
# Name: 999, dtype: object

# %%
data.loc[99,"Total Revenue"]
# Out:
# 424435.3

# %%
data.loc[data["Units Sold"]<1000]
# Out:
#                                 Region                         Country  \
# 20               Australia and Oceania  Federated States of Micronesia
# 23                                Asia                        Mongolia
# 24   Central America and the Caribbean                         Grenada
# 32                  Sub-Saharan Africa                           Benin
# 42        Middle East and North Africa                          Turkey
# ..                                 ...                             ...
# 967  Central America and the Caribbean          Saint Kitts and Nevis
# 970  Central America and the Caribbean          Saint Kitts and Nevis
# 981              Australia and Oceania                            Fiji
# 990                 Sub-Saharan Africa                            Mali
# 996                             Europe                         Georgia
#
#      Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
newdf=data.loc[data["Units Sold"]>5000]
print(newdf)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 4              Sub-Saharan Africa                  Chad      Fruits
# 5                          Europe               Armenia      Cereal
# 7                          Europe            Montenegro     Clothes
# 14                           Asia              Maldives      Fruits
# ..                            ...                   ...         ...
# 989         Australia and Oceania                  Fiji      Cereal
# 993         Australia and Oceania                Samoa    Baby Food
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
newdf["Country"]
# Out:
# 0                     Libya
# 4                      Chad
# 5                   Armenia
# 7                Montenegro
# 14                 Maldives
#                ...
# 989                    Fiji
# 993                  Samoa
# 995              Azerbaijan
# 997    United Arab Emirates
# 998                 Finland
# Name: Country, Length: 511, dtype: object

# %%
cd=pd.read_csv("sales_record.csv")
cd.to_excel("sales_record.xlsx")
cd=pd.read_excel("sales_record.xlsx")
print(cd)
# Out:
#      Unnamed: 0                        Region               Country  \
# 0             0  Middle East and North Africa                 Libya
# 1             1                 North America                Canada
# 2             2  Middle East and North Africa                 Libya
# 3             3                          Asia                 Japan
# 4             4            Sub-Saharan Africa                  Chad
# ..          ...                           ...                   ...
# 995         995  Middle East and North Africa            Azerbaijan
# 996         996                        Europe               Georgia
# 997         997  Middle East and North Africa  United Arab Emirates
# 998         998                        Europe               Finland
# 999         999                        Europe              Portugal
#
#       Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0     Cosmetics       Offline              M  10/18/2014  686800706
# ...
